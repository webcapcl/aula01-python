# %%
nome = "João Silva"
idade = 25
profissao = "desenvolvedor"
print("Seu nome é", nome)
print("Sua idade:",  idade)
print("sua Profissão", profissao)
# Out:
# Seu nome é João Silva
# Sua idade: 25
# sua Profissão desenvolvedor

# %%
produto = "notebook"
marca = "dell"
preco = 4500
print(produto)
print(marca)
print(f"Preço R$ {preco:.2f}")
# Out:
# notebook
# dell
# Preço R$ 4500.00

# %%
num1 = 12
num2 =  6
num3 = 12
num4 = 6
soma  = num1 + num2
subtracao = num1 - num2
mult = num1 * num2
divisao = num1 / num2
# resultado da divisao em numero inteiro
divisao2 = int(num3 / num4)

print("Numero 1:",num1)
print("Numero 2:",num2)
print(soma)
print(subtracao)
print(mult)
print(divisao)
print(divisao2)
# Out:
# Numero 1: 12
# Numero 2: 6
# 18
# 6
# 72
# 2.0
# 2

# %%
num1 = 7
num2 =2
soma = num1 + num2
subtracao = num1 - num2
mult = num1 * num2
div =  num1 / num2
potenciacao = num1 ** num2
print("Numero1:", num1 )
print("Numero2:", num2 )
print(soma)
print(subtracao)
print(mult)
print(div)
print(potenciacao)
# Out:
# Numero1: 7
# Numero2: 2
# 9
# 5
# 14
# 3.5
# 49

# %%
num1 = 15
num2 = 5
soma = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
# divisão número inteiro
div2 = int(num1 / num2)
potenciacao = num1 ** num2
print("Número1:",num1)
print("Número2:",num2)
print(soma)
print(sub)
print(mult)
print(div)
print(div2)
print(potenciacao)
print(f"{soma}\n{sub}\n{mult}")
# Out:
# Número1: 15
# Número2: 5
# 20
# 10
# 75
# 3.0
# 3
# 759375
# 20
# 10
# 75
